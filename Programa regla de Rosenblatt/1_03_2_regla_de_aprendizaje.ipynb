# %% [markdown]
# # Ejercicio Realizado por ADAIR HERNANDEZ VALDIVIA

# %% [markdown]
# # Regla de aprendizaje de Rosenblatt
#
# (4 puntos posibles)
#
# El primer esfuerzo para que el perceptrón aprendiera a partir de datos fue la regla de aprendizaje presentada por Frank Rosenblatt. En este notebook aplicaremos dicha regla para observar el comportamiento sobre un conjuinto de datos sintético.
#
# @juan1rving

# %%
import nni.functions as nf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.inspection import DecisionBoundaryDisplay
from matplotlib.colors import ListedColormap

colors = ['red', 'blue']

# %%
# Generar datos sintéticos
X, y = nf.datosSinteticos()

cmap = ListedColormap(colors[:len(np.unique(y))])

# Visualizar los datos
fig = plt.figure()
ax = fig.subplots()
ax.scatter(X.loc[y==0, 'x1'], X.loc[y==0, 'x2'], color='red', marker='o', label='Clase 0')
ax.scatter(X.loc[y==1, 'x1'], X.loc[y==1, 'x2'], color='blue', marker='s', label='Clase 1')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Datos sintéticos')
ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Perceptrón
#
# A diferencia del ejercicio previo. En esta ocasión implementaremos el perceptrón como una clase.

# %%
class Perceptron:
    def __init__(self, n_entradas, f_activacion):
        self.W = np.zeros((n_entradas,))
        self.b = 0.0
        self._f_activacion = f_activacion

    def inferencia(self, X):
        h = np.dot(X, self.W) + self.b
        return self._f_activacion(h)
    
def escalon(x):
    return np.where(x >= 0, 1, 0)

# %% [markdown]
# ## Inicialización
#
# El primer paso consite en inicializar los pesos.
#
# Para inicializar los pesos con una distribución normal, podemos utilizar la función `numpy.random.normal`. Esta función permite especificar la media (`loc`), la desviación estándar (`scale`) y el número de valores a generar (`size`). Por ejemplo, `np.random.normal(loc=0, scale=1, size=(2,))` genera dos valores aleatorios con media 0 y desviación estándar 1. Esta inicialización es útil para romper la simetría y facilitar el aprendizaje del perceptrón.

# %%
# Crear una instancia del perceptrón
clasificador = Perceptron(n_entradas=2, f_activacion=escalon)
print("Pesos iniciales:", clasificador.W)
print("Bias inicial:", clasificador.b)
# Out:
# Pesos iniciales: [0. 0.]
# Bias inicial: 0.0

# %%
# Inicialización de parámetros (1 punto)
clasificador.W = np.random.normal(loc=0, scale=1, size=(2,))
clasificador.b = np.random.normal(loc=0, scale=1)
print("Pesos después de la inicialización:", clasificador.W)
print("Bias después de la inicialización:", clasificador.b)
# Out:
# Pesos después de la inicialización: [1.5180199  0.66349871]
# Bias después de la inicialización: -1.1375725637039047

# %% [markdown]
# ### Función de pérdida
#
# La función de pérdida nos indica que tanto nos estamos equivocando en el conjunto de datos completo.
#
# En este notebook usaremos la suma de los errores absolutos
# $$
# \mathcal{L} = SAE = \sum_\mu | y^\mu - \hat{y}^\mu |
# $$

# %%
# implementa la función de pérdida (1 punto)
def perdidaSAE(y_true, y_pred):
    # Suma de errores absolutos
    suma = 0
    for i in range(len(y_true)):
        suma += abs(y_true[i] - y_pred[i])

    return suma

y_pred = clasificador.inferencia(X)
print("Pérdida inicial (SAE):", perdidaSAE(y, y_pred))
# Out:
# Pérdida inicial (SAE): 77

# %% [markdown]
# A continuación visualizaremos el rendimiento del clasificador de forma gráfica

# %%
x1, x2 = np.meshgrid(
np.linspace(X.iloc[:,0].min(), X.iloc[:,0].max(), num=200),
    np.linspace(X.iloc[:,1].min(), X.iloc[:,1].max(), num=200)
)
grid = np.vstack([x1.ravel(), x2.ravel()]).T
y_pred = np.reshape(clasificador.inferencia(grid), x1.shape)

fig = plt.figure()
ax = fig.subplots()
display = DecisionBoundaryDisplay(xx0=x1, xx1=x2, response=y_pred)
display.plot(ax=ax, plot_method='contourf', cmap=cmap, alpha=0.3)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.scatter(X.loc[y==0, 'x1'], X.loc[y==0, 'x2'], color='red', marker='o', label='clase 0')
ax.scatter(X.loc[y==1, 'x1'], X.loc[y==1, 'x2'], color='blue', marker='s', label='clase 1')
ax.set_title('Clasificador inicial (sin entrenar)')
ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Regla de aprendizaje
#
# Primero, recordemos que la regla de aprendizase se basa en que cada error no guia hacia donde mover los pesos. Es decir usamos el error residual:
#
# $$
# e^\mu = y^\mu - \hat{y}^\mu
# $$
#
# Una vez definido el error residual observemos que la regla de aprendizaje se calcula como
#
# $$
# W^{t+1} = W^{t} + \eta (y - \hat{y}) X
# $$
#
# Y se repite el cálculo tantas veces como deseemos.

# %%
## Implementa la regla de aprendizaje (2 puntos)
class ReglaDeAprendizaje:
    def __init__(self, tasa_aprendizaje=0.1):
        self.tasa_aprendizaje = tasa_aprendizaje

    def actualizar(self, perceptron, X, y):
        for xi, target in zip(X.values, y.values):
            output = perceptron.inferencia(xi)
            error = target - output
            perceptron.W = perceptron.W + self.tasa_aprendizaje * error * xi # Actualiza los pesos
            perceptron.b = perceptron.b + self.tasa_aprendizaje * error # Actualiza el bias

# %%
# Configuración del entrenamiento
tasa_aprendizaje = 0.5
n_epocas = 300 #Configura el número de épocas

# %%
optimizador = ReglaDeAprendizaje(tasa_aprendizaje=tasa_aprendizaje)

historial_perdida = []

for epoca in range(n_epocas):
    y_pred = clasificador.inferencia(X)
    perdida = perdidaSAE(y, y_pred)
    print(f"Época {epoca+1}: Pérdida (SAE): {perdida}")
    historial_perdida.append(perdida)
    optimizador.actualizar(clasificador, X, y)

# Visualizar la pérdida a lo largo de las épocas
plt.plot(range(1, n_epocas + 1), historial_perdida, marker='o')
plt.xlabel('Época')
plt.ylabel('Pérdida (SAE)')
plt.title('Evolución de la pérdida durante el entrenamiento')
plt.grid()
plt.show()
# Out:
# Época 1: Pérdida (SAE): 77
# Época 2: Pérdida (SAE): 91
# Época 3: Pérdida (SAE): 96
# Época 4: Pérdida (SAE): 70
# Época 5: Pérdida (SAE): 87
# Época 6: Pérdida (SAE): 81
# Época 7: Pérdida (SAE): 81
# Época 8: Pérdida (SAE): 78
# Época 9: Pérdida (SAE): 75
# Época 10: Pérdida (SAE): 43
# Época 11: Pérdida (SAE): 64
# Época 12: Pérdida (SAE): 29
# Época 13: Pérdida (SAE): 64
# Época 14: Pérdida (SAE): 55
# Época 15: Pérdida (SAE): 31
# Época 16: Pérdida (SAE): 26
# Época 17: Pérdida (SAE): 58
# Época 18: Pérdida (SAE): 52
# Época 19: Pérdida (SAE): 52
# Época 20: Pérdida (SAE): 55
# Época 21: Pérdida (SAE): 23
# Época 22: Pérdida (SAE): 20
# Época 23: Pérdida (SAE): 52
# Época 24: Pérdida (SAE): 21
# Época 25: Pérdida (SAE): 52
# Época 26: Pérdida (SAE): 42
# Época 27: Pérdida (SAE): 42
# Época 28: Pérdida (SAE): 42
# Época 29: Pérdida (SAE): 41
# Época 30: Pérdida (SAE): 45
# Época 31: Pérdida (SAE): 15
# Época 32: Pérdida (SAE): 37
# Época 33: Pérdida (SAE): 36
# Época 34: Pérdida (SAE): 36
# Época 35: Pérdida (SAE): 36
# Época 36: Pérdida (SAE): 41
# Época 37: Pérdida (SAE): 14
# Época 38: Pérdida (SAE): 30
# Época 39: Pérdida (SAE): 14
# Época 40: Pérdida (SAE): 30
# Época 41: Pérdida (SAE): 23
# Época 42: Pérdida (SAE): 30
# Época 43: Pérdida (SAE): 23
# Época 44: Pérdida (SAE): 29
# Época 45: Pérdida (SAE): 23
# Época 46: Pérdida (SAE): 29
# Época 47: Pérdida (SAE): 27
# Época 48: Pérdida (SAE): 14
# Época 49: Pérdida (SAE): 29
# Época 50: Pérdida (SAE): 27
# Época 51: Pérdida (SAE): 10
# Época 52: Pérdida (SAE): 27
# Época 53: Pérdida (SAE): 10
# Época 54: Pérdida (SAE): 24
# Época 55: Pérdida (SAE): 10
# Época 56: Pérdida (SAE): 24
# Época 57: Pérdida (SAE): 10
# Época 58: Pérdida (SAE): 20
# Época 59: Pérdida (SAE): 6
# Época 60: Pérdida (SAE): 12
# Época 61: Pérdida (SAE): 25
# Época 62: Pérdida (SAE): 10
# Época 63: Pérdida (SAE): 21
# Época 64: Pérdida (SAE): 10
# Época 65: Pérdida (SAE): 23
# Época 66: Pérdida (SAE): 9
# Época 67: Pérdida (SAE): 23
# Época 68: Pérdida (SAE): 10
# Época 69: Pérdida (SAE): 20
# Época 70: Pérdida (SAE): 10
# Época 71: Pérdida (SAE): 20
# Época 72: Pérdida (SAE): 7
# Época 73: Pérdida (SAE): 17
# Época 74: Pérdida (SAE): 14
# Época 75: Pérdida (SAE): 8
# Época 76: Pérdida (SAE): 20
# Época 77: Pérdida (SAE): 6
# Época 78: Pérdida (SAE): 8
# Época 79: Pérdida (SAE): 20
# Época 80: Pérdida (SAE): 6
# Época 81: Pérdida (SAE): 8
# Época 82: Pérdida (SAE): 20
# Época 83: Pérdida (SAE): 6
# Época 84: Pérdida (SAE): 8
# Época 85: Pérdida (SAE): 20
# Época 86: Pérdida (SAE): 6
# Época 87: Pérdida (SAE): 6
# Época 88: Pérdida (SAE): 17
# Época 89: Pérdida (SAE): 16
# Época 90: Pérdida (SAE): 9
# Época 91: Pérdida (SAE): 12
# Época 92: Pérdida (SAE): 10
# Época 93: Pérdida (SAE): 13
# Época 94: Pérdida (SAE): 6
# Época 95: Pérdida (SAE): 17
# Época 96: Pérdida (SAE): 12
# Época 97: Pérdida (SAE): 9
# Época 98: Pérdida (SAE): 13
# Época 99: Pérdida (SAE): 6
# Época 100: Pérdida (SAE): 17
# Época 101: Pérdida (SAE): 18
# Época 102: Pérdida (SAE): 6
# Época 103: Pérdida (SAE): 6
# Época 104: Pérdida (SAE): 17
# Época 105: Pérdida (SAE): 12
# Época 106: Pérdida (SAE): 6
# Época 107: Pérdida (SAE): 8
# Época 108: Pérdida (SAE): 12
# Época 109: Pérdida (SAE): 6
# Época 110: Pérdida (SAE): 17
# Época 111: Pérdida (SAE): 18
# Época 112: Pérdida (SAE): 5
# Época 113: Pérdida (SAE): 6
# Época 114: Pérdida (SAE): 8
# Época 115: Pérdida (SAE): 12
# Época 116: Pérdida (SAE): 8
# Época 117: Pérdida (SAE): 5
# Época 118: Pérdida (SAE): 6
# Época 119: Pérdida (SAE): 8
# Época 120: Pérdida (SAE): 12
# Época 121: Pérdida (SAE): 9
# Época 122: Pérdida (SAE): 13
# Época 123: Pérdida (SAE): 6
# Época 124: Pérdida (SAE): 17
# Época 125: Pérdida (SAE): 12
# Época 126: Pérdida (SAE): 8
# Época 127: Pérdida (SAE): 12
# Época 128: Pérdida (SAE): 6
# Época 129: Pérdida (SAE): 17
# Época 130: Pérdida (SAE): 12
# Época 131: Pérdida (SAE): 6
# Época 132: Pérdida (SAE): 16
# Época 133: Pérdida (SAE): 9
# Época 134: Pérdida (SAE): 6
# Época 135: Pérdida (SAE): 6
# Época 136: Pérdida (SAE): 16
# Época 137: Pérdida (SAE): 9
# Época 138: Pérdida (SAE): 6
# Época 139: Pérdida (SAE): 6
# Época 140: Pérdida (SAE): 16
# Época 141: Pérdida (SAE): 12
# Época 142: Pérdida (SAE): 6
# Época 143: Pérdida (SAE): 8
# Época 144: Pérdida (SAE): 13
# Época 145: Pérdida (SAE): 6
# Época 146: Pérdida (SAE): 16
# Época 147: Pérdida (SAE): 8
# Época 148: Pérdida (SAE): 6
# Época 149: Pérdida (SAE): 6
# Época 150: Pérdida (SAE): 16
# Época 151: Pérdida (SAE): 9
# Época 152: Pérdida (SAE): 6
# Época 153: Pérdida (SAE): 6
# Época 154: Pérdida (SAE): 8
# Época 155: Pérdida (SAE): 4
# Época 156: Pérdida (SAE): 6
# Época 157: Pérdida (SAE): 8
# Época 158: Pérdida (SAE): 3
# Época 159: Pérdida (SAE): 6
# Época 160: Pérdida (SAE): 6
# Época 161: Pérdida (SAE): 8
# Época 162: Pérdida (SAE): 6
# Época 163: Pérdida (SAE): 6
# Época 164: Pérdida (SAE): 8
# Época 165: Pérdida (SAE): 3
# Época 166: Pérdida (SAE): 6
# Época 167: Pérdida (SAE): 6
# Época 168: Pérdida (SAE): 8
# Época 169: Pérdida (SAE): 4
# Época 170: Pérdida (SAE): 6
# Época 171: Pérdida (SAE): 8
# Época 172: Pérdida (SAE): 4
# Época 173: Pérdida (SAE): 6
# Época 174: Pérdida (SAE): 8
# Época 175: Pérdida (SAE): 6
# Época 176: Pérdida (SAE): 6
# Época 177: Pérdida (SAE): 8
# Época 178: Pérdida (SAE): 6
# Época 179: Pérdida (SAE): 6
# Época 180: Pérdida (SAE): 8
# Época 181: Pérdida (SAE): 6
# Época 182: Pérdida (SAE): 6
# Época 183: Pérdida (SAE): 8
# Época 184: Pérdida (SAE): 3
# Época 185: Pérdida (SAE): 6
# Época 186: Pérdida (SAE): 8
# Época 187: Pérdida (SAE): 6
# Época 188: Pérdida (SAE): 6
# Época 189: Pérdida (SAE): 8
# Época 190: Pérdida (SAE): 6
# Época 191: Pérdida (SAE): 6
# Época 192: Pérdida (SAE): 8
# Época 193: Pérdida (SAE): 6
# Época 194: Pérdida (SAE): 6
# Época 195: Pérdida (SAE): 8
# Época 196: Pérdida (SAE): 3
# Época 197: Pérdida (SAE): 6
# Época 198: Pérdida (SAE): 7
# Época 199: Pérdida (SAE): 3
# Época 200: Pérdida (SAE): 6
# Época 201: Pérdida (SAE): 6
# Época 202: Pérdida (SAE): 8
# Época 203: Pérdida (SAE): 4
# Época 204: Pérdida (SAE): 6
# Época 205: Pérdida (SAE): 8
# Época 206: Pérdida (SAE): 3
# Época 207: Pérdida (SAE): 6
# Época 208: Pérdida (SAE): 8
# Época 209: Pérdida (SAE): 5
# Época 210: Pérdida (SAE): 6
# Época 211: Pérdida (SAE): 8
# Época 212: Pérdida (SAE): 4
# Época 213: Pérdida (SAE): 6
# Época 214: Pérdida (SAE): 8
# Época 215: Pérdida (SAE): 6
# Época 216: Pérdida (SAE): 6
# Época 217: Pérdida (SAE): 8
# Época 218: Pérdida (SAE): 6
# Época 219: Pérdida (SAE): 6
# Época 220: Pérdida (SAE): 8
# Época 221: Pérdida (SAE): 6
# Época 222: Pérdida (SAE): 6
# Época 223: Pérdida (SAE): 8
# Época 224: Pérdida (SAE): 4
# Época 225: Pérdida (SAE): 6
# Época 226: Pérdida (SAE): 8
# Época 227: Pérdida (SAE): 5
# Época 228: Pérdida (SAE): 6
# Época 229: Pérdida (SAE): 8
# Época 230: Pérdida (SAE): 5
# Época 231: Pérdida (SAE): 6
# Época 232: Pérdida (SAE): 8
# Época 233: Pérdida (SAE): 6
# Época 234: Pérdida (SAE): 6
# Época 235: Pérdida (SAE): 8
# Época 236: Pérdida (SAE): 6
# Época 237: Pérdida (SAE): 6
# Época 238: Pérdida (SAE): 8
# Época 239: Pérdida (SAE): 6
# Época 240: Pérdida (SAE): 6
# Época 241: Pérdida (SAE): 8
# Época 242: Pérdida (SAE): 4
# Época 243: Pérdida (SAE): 6
# Época 244: Pérdida (SAE): 8
# Época 245: Pérdida (SAE): 5
# Época 246: Pérdida (SAE): 6
# Época 247: Pérdida (SAE): 8
# Época 248: Pérdida (SAE): 5
# Época 249: Pérdida (SAE): 6
# Época 250: Pérdida (SAE): 8
# Época 251: Pérdida (SAE): 6
# Época 252: Pérdida (SAE): 6
# Época 253: Pérdida (SAE): 8
# Época 254: Pérdida (SAE): 6
# Época 255: Pérdida (SAE): 6
# Época 256: Pérdida (SAE): 8
# Época 257: Pérdida (SAE): 6
# Época 258: Pérdida (SAE): 6
# Época 259: Pérdida (SAE): 8
# Época 260: Pérdida (SAE): 5
# Época 261: Pérdida (SAE): 6
# Época 262: Pérdida (SAE): 8
# Época 263: Pérdida (SAE): 5
# Época 264: Pérdida (SAE): 6
# Época 265: Pérdida (SAE): 8
# Época 266: Pérdida (SAE): 5
# Época 267: Pérdida (SAE): 6
# Época 268: Pérdida (SAE): 8
# Época 269: Pérdida (SAE): 6
# Época 270: Pérdida (SAE): 6
# Época 271: Pérdida (SAE): 8
# Época 272: Pérdida (SAE): 6
# Época 273: Pérdida (SAE): 6
# Época 274: Pérdida (SAE): 8
# Época 275: Pérdida (SAE): 6
# Época 276: Pérdida (SAE): 6
# Época 277: Pérdida (SAE): 7
# Época 278: Pérdida (SAE): 5
# Época 279: Pérdida (SAE): 6
# Época 280: Pérdida (SAE): 8
# Época 281: Pérdida (SAE): 6
# Época 282: Pérdida (SAE): 6
# Época 283: Pérdida (SAE): 8
# Época 284: Pérdida (SAE): 6
# Época 285: Pérdida (SAE): 6
# Época 286: Pérdida (SAE): 8
# Época 287: Pérdida (SAE): 6
# Época 288: Pérdida (SAE): 6
# Época 289: Pérdida (SAE): 7
# Época 290: Pérdida (SAE): 5
# Época 291: Pérdida (SAE): 6
# Época 292: Pérdida (SAE): 8
# Época 293: Pérdida (SAE): 5
# Época 294: Pérdida (SAE): 6
# Época 295: Pérdida (SAE): 7
# Época 296: Pérdida (SAE): 5
# Época 297: Pérdida (SAE): 6
# Época 298: Pérdida (SAE): 8
# Época 299: Pérdida (SAE): 6
# Época 300: Pérdida (SAE): 6

# %%
x1, x2 = np.meshgrid(
np.linspace(X.iloc[:,0].min(), X.iloc[:,0].max(), num=200),
    np.linspace(X.iloc[:,1].min(), X.iloc[:,1].max(), num=200)
)
grid = np.vstack([x1.ravel(), x2.ravel()]).T
y_pred = np.reshape(clasificador.inferencia(grid), x1.shape)

fig = plt.figure()
ax = fig.subplots()
display = DecisionBoundaryDisplay(xx0=x1, xx1=x2, response=y_pred)
display.plot(ax=ax, plot_method='contourf', cmap=cmap, alpha=0.3)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.scatter(X.loc[y==0, 'x1'], X.loc[y==0, 'x2'], color='red', marker='o', label='clase 0')
ax.scatter(X.loc[y==1, 'x1'], X.loc[y==1, 'x2'], color='blue', marker='s', label='clase 1')
ax.set_title('Clasificador después del entrenamiento')
ax.legend(loc='upper left')
plt.show()
